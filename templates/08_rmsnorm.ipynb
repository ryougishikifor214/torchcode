# %% [markdown]
# <a href="https://colab.research.google.com/github/ryougishikifor214/torchcode/blob/master/templates/08_rmsnorm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/08_rmsnorm.ipynb)
#
# # 🟡 Medium: Implement RMSNorm
#
# Implement **Root Mean Square Layer Normalization** — the normalization used in LLaMA, Gemma, etc.
#
# $$\text{RMSNorm}(x) = \frac{x}{\text{RMS}(x)} \cdot w, \quad \text{RMS}(x) = \sqrt{\frac{1}{d}\sum x_i^2 + \epsilon}$$
#
# ### Signature
# ```python
# def rms_norm(x: torch.Tensor, weight: torch.Tensor, eps: float = 1e-6) -> torch.Tensor:
#     # Normalize over the last dimension. No mean subtraction (unlike LayerNorm).
# ```
#
# ### Rules
# - Do **NOT** use any built-in norm layers
# - Normalize over `dim=-1`
# - Must support autograd

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.1 MB/s eta 0:00:00

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def rms_norm(x, weight, eps=1e-6):
    # pass  # Replace this
    rms_norm=torch.sqrt(torch.mean(x**2,dim=-1,keepdim=True)+eps)
    return weight*x/rms_norm

# %%
# 🧪 Debug
x = torch.randn(2, 8)
w = torch.ones(8)
out = rms_norm(x, w)
print("Output shape:", out.shape)
print("RMS of output:", out.pow(2).mean(dim=-1).sqrt())  # should be ~1
# Out:
# Output shape: torch.Size([2, 8])
# RMS of output: tensor([1.0000, 1.0000])

# %%
from torch_judge import check
check('rmsnorm')
# Out:
# 🧪 Testing: Implement RMSNorm (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Basic behavior (1.2ms)
#   ✅ [2/4] With learned weight (0.6ms)
#   ✅ [3/4] 3-D input (1.4ms)
#   ✅ [4/4] Gradient flow (1.2ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (4.5ms total)
#   Progress saved. Run status() to see your dashboard.

# %%
from torch_judge import status
status()
# Out:
# ────────────────────────────────────────────────────────
#   🔥 TorchCode Progress: 1/40 solved
# ────────────────────────────────────────────────────────
#   ⏳ cross_entropy        [Easy]
#      Cross-Entropy Loss
#   ⏳ dropout              [Easy]
#      Implement Dropout
#   ⏳ embedding            [Easy]
#      Embedding Layer
#   ⏳ gelu                 [Easy]
#      GELU Activation
#   ⏳ gradient_accumulation [Easy]
#      Gradient Accumulation
#   ⏳ gradient_clipping    [Easy]
#      Gradient Norm Clipping
#   ⏳ relu                 [Easy]
#      Implement ReLU
#   ⏳ softmax              [Easy]
#      Implement Softmax
#   ⏳ weight_init          [Easy]
#      Kaiming Initialization
#   ⏳ adam                 [Medium]
#      Adam Optimizer
#   ⏳ batchnorm            [Medium]
#      Implement BatchNorm
#   ⏳ beam_search          [Medium]
#      Beam Search Decoding
#   ⏳ conv2d               [Medium]
#      2D Convolution
#   ⏳ cosine_lr            [Medium]
#      Cosine LR Scheduler with Warmup
#   ⏳ cross_attention      [Medium]
#      Multi-Head Cross-Attention
#   ⏳ layernorm            [Medium]
#      Implement LayerNorm
#   ⏳ linear               [Medium]
#      Simple Linear Layer
#   ⏳ linear_regression    [Medium]
#      Linear Regression
#   ⏳ lora                 [Medium]
#      LoRA (Low-Rank Adaptation)
#   ⏳ mlp                  [Medium]
#      SwiGLU MLP
#   ✅ rmsnorm              [Medium]  ⚡ 44.7ms  (1 attempts)
#      Implement RMSNorm
#   ⏳ topk_sampling        [Medium]
#      Top-k / Top-p Sampling
#   ⏳ vit_patch            [Medium]
#      ViT Patch Embedding
#   ⏳ attention            [Hard]
#      Softmax Attention
#   ⏳ bpe                  [Hard]
#      Byte-Pair Encoding (BPE)
#   ⏳ causal_attention     [Hard]
#      Causal Self-Attention
#   ⏳ dpo_loss             [Hard]
#      DPO (Direct Preference Optimization) Loss
#   ⏳ flash_attention      [Hard]
#      Flash Attention (Tiled)
#   ⏳ gpt2_block           [Hard]
#      GPT-2 Transformer Block
#   ⏳ gqa                  [Hard]
#      Grouped Query Attention
#   ⏳ grpo_loss            [Hard]
#      GRPO (Group Relative Policy Optimization) Loss
#   ⏳ int8_quantization    [Hard]
#      INT8 Quantized Linear
#   ⏳ kv_cache             [Hard]
#      KV Cache Attention
#   ⏳ linear_attention     [Hard]
#      Linear Self-Attention
#   ⏳ mha                  [Hard]
#      Multi-Head Attention
#   ⏳ moe                  [Hard]
#      Mixture of Experts (MoE)
#   ⏳ ppo_loss             [Hard]
#      PPO (Proximal Policy Optimization) Clipped Loss
#   ⏳ rope                 [Hard]
#      Rotary Position Embedding (RoPE)
#   ⏳ sliding_window       [Hard]
#      Sliding Window Attention
#   ⏳ speculative_decoding [Hard]
#      Speculative Decoding
# ────────────────────────────────────────────────────────
